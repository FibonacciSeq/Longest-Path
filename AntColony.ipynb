# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import random

# %%
#Funcion that loads graph from file
def inputGraph(filePath):
    graph = nx.read_graphml(filePath)
    return graph

# %%
def graphToAdjasencyMatrix(graph):
    return nx.adjacency_matrix(graph).toarray()

# %%
def visualizeGraph(graph):
    nx.draw(graph, with_labels=True)
    plt.show()

# %%
filePath = "random_graph.graphml"
graph = inputGraph(filePath)
adjMatrix = graphToAdjasencyMatrix(graph)
visualizeGraph(graph)
# Out:
# /tmp/ipykernel_4052/250109804.py:2: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return nx.adjacency_matrix(graph).toarray()

# %%
print(graph)
# Out:
# Graph with 1000 nodes and 49832 edges
